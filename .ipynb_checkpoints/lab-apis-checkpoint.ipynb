# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\reetu\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\reetu\anaconda3\lib\site-packages (from spotipy) (5.0.7)
# Requirement already satisfied: requests>=2.25.0 in c:\users\reetu\anaconda3\lib\site-packages (from spotipy) (2.32.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\reetu\anaconda3\lib\site-packages (from spotipy) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\reetu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reetu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reetu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.6.2)

# %%
CLIENT_ID = "5eae08977034419ebdafa2f6e0efa6b7"
CLIENT_SECRET = "621cc79052b041f9b77254fbc65ee158"

# %%
from functions import get_top_tracks, get_top_tracks, find_related_artists_list
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from function import get_top_tracks, get_top_tracks, find_related_artists_list
#       2 import spotipy
#       3 from spotipy.oauth2 import SpotifyClientCredentials
#
# ImportError: cannot import name 'find_related_artists_list' from 'function' (C:\Users\reetu\OneDrive\Documents\GitHub\lab-apis\function.py)

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#      'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#      'id': '6rePArBMb5nLWEaY9aQqL4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 294573,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70918596'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#     'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#     'id': '0SiywuOBRcynK0uKGWdCnn',
#     'is_local': False,
#     'name': 'Bad Romance',
#     'popularity': 82,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#        'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#        'id': '12GqGscKJx3aE4t07u7eVZ',
#        'name': 'Peso Pluma',
#        'type': 'artist',
#        'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#      'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#      'id': '4jox3ip1I39DFC2B7R5qLH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba',
#        'width': 64}],
#      'name': 'GÉNESIS',
#      'release_date': '2023-06-29',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#       'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#       'id': '12GqGscKJx3aE4t07u7eVZ',
#       'name': 'Peso Pluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#       'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#       'id': '6Sbl0NT50roqWvy746MfVf',
#       'name': 'Gabito Ballesteros',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#       'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#       'id': '7Gi6gjaWy3DxyilpF1a8Is',
#       'name': 'Junior H',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 212878,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM7282306246'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#     'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#     'id': '7mXuWTczZNxG5EDcjFEuJR',
#     'is_local': False,
#     'name': 'LADY GAGA',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec439edcef8f1b71e88cfeb7d200db274901123b?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#      'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#      'id': '1jpUMnKpRlng1OJN7LJauV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273631810af03785dbad83f5c81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02631810af03785dbad83f5c81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851631810af03785dbad83f5c81',
#        'width': 64}],
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 237200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70824409'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5R8dQOPq8haW94K7mgERlO'},
#     'href': 'https://api.spotify.com/v1/tracks/5R8dQOPq8haW94K7mgERlO',
#     'id': '5R8dQOPq8haW94K7mgERlO',
#     'is_local': False,
#     'name': 'Poker Face',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5R8dQOPq8haW94K7mgERlO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#      'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#      'id': '3edjzMAVB9RYRd4UcZBchx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#        'width': 64}],
#      'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 210200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71813195'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2rbDhOo9Fh61Bbu23T2qCk'},
#     'href': 'https://api.spotify.com/v1/tracks/2rbDhOo9Fh61Bbu23T2qCk',
#     'id': '2rbDhOo9Fh61Bbu23T2qCk',
#     'is_local': False,
#     'name': 'Always Remember Us This Way',
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#      'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#      'id': '2KkMVsxymoNR7hRmBcMttd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#        'width': 64}],
#      'name': 'Born This Way',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 249066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71104998'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0QkWikH5Z3U0f79T9iuF6c'},
#     'href': 'https://api.spotify.com/v1/tracks/0QkWikH5Z3U0f79T9iuF6c',
#     'id': '0QkWikH5Z3U0f79T9iuF6c',
#     'is_local': False,
#     'name': 'Judas',
#     'popularity': 71,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0QkWikH5Z3U0f79T9iuF6c'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#      'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#      'id': '1jpUMnKpRlng1OJN7LJauV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273631810af03785dbad83f5c81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02631810af03785dbad83f5c81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851631810af03785dbad83f5c81',
#        'width': 64}],
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#       'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#       'id': '7fObcBw9VM3x7ntWKCYl0z',
#       'name': "Colby O'Donis",
#       'type': 'artist',
#       'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 241933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70807646'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2x7MyWybabEz6Y6wvHuwGE'},
#     'href': 'https://api.spotify.com/v1/tracks/2x7MyWybabEz6Y6wvHuwGE',
#     'id': '2x7MyWybabEz6Y6wvHuwGE',
#     'is_local': False,
#     'name': 'Just Dance',
#     'popularity': 74,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2x7MyWybabEz6Y6wvHuwGE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'MY',
#       'MT',
#       'MX',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DGZdMi124iOOih9GMlhN2'},
#      'href': 'https://api.spotify.com/v1/albums/6DGZdMi124iOOih9GMlhN2',
#      'id': '6DGZdMi124iOOih9GMlhN2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bfd247438980173d32fd5ba8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bfd247438980173d32fd5ba8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bfd247438980173d32fd5ba8',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-08-05',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:6DGZdMi124iOOih9GMlhN2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'MY',
#      'MT',
#      'MX',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 274213,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70905526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lwavw59UjXUPJZtKNdFYp'},
#     'href': 'https://api.spotify.com/v1/tracks/4lwavw59UjXUPJZtKNdFYp',
#     'id': '4lwavw59UjXUPJZtKNdFYp',
#     'is_local': False,
#     'name': 'Alejandro',
#     'popularity': 70,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4lwavw59UjXUPJZtKNdFYp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#      'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#      'id': '5maeycU97NHBgwRr2h2A4O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#        'width': 64}],
#      'name': 'Born This Way (Special Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 244760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71106449'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11BKm0j4eYoCPPpCONAVwA'},
#     'href': 'https://api.spotify.com/v1/tracks/11BKm0j4eYoCPPpCONAVwA',
#     'id': '11BKm0j4eYoCPPpCONAVwA',
#     'is_local': False,
#     'name': 'Bloody Mary',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:11BKm0j4eYoCPPpCONAVwA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#      'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#      'id': '2KkMVsxymoNR7hRmBcMttd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#        'width': 64}],
#      'name': 'Born This Way',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 320586,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71106458'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0JNdS1n0ifOP25XvhwAMgM'},
#     'href': 'https://api.spotify.com/v1/tracks/0JNdS1n0ifOP25XvhwAMgM',
#     'id': '0JNdS1n0ifOP25XvhwAMgM',
#     'is_local': False,
#     'name': 'The Edge Of Glory',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:0JNdS1n0ifOP25XvhwAMgM'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
# ...
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1o716Hgxa1s7yWCXxy8saX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#      'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#      'id': '3edjzMAVB9RYRd4UcZBchx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#        'width': 64}],
#      'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#       'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#       'id': '4VIvfOurcf0vuLRxLkGnIG',
#       'name': 'Bradley Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 217212,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71815945'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6QfS2wq5sSC1xAJCQsTSlj'},
#     'href': 'https://api.spotify.com/v1/tracks/6QfS2wq5sSC1xAJCQsTSlj',
#     'id': '6QfS2wq5sSC1xAJCQsTSlj',
#     'is_local': False,
#     'name': 'Shallow - Radio Edit',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6QfS2wq5sSC1xAJCQsTSlj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#      'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#      'id': '3edjzMAVB9RYRd4UcZBchx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#        'width': 64}],
#      'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 202640,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71813201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4gdfWGyzB9j4ZVc2JWdpv2'},
#     'href': 'https://api.spotify.com/v1/tracks/4gdfWGyzB9j4ZVc2JWdpv2',
#     'id': '4gdfWGyzB9j4ZVc2JWdpv2',
#     'is_local': False,
#     'name': 'Hair Body Face',
#     'popularity': 47,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:4gdfWGyzB9j4ZVc2JWdpv2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#      'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#      'id': '5maeycU97NHBgwRr2h2A4O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#        'width': 64}],
#      'name': 'Born This Way (Special Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 320546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71106458'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6uxYfENm7zw050dNUi031W'},
#     'href': 'https://api.spotify.com/v1/tracks/6uxYfENm7zw050dNUi031W',
#     'id': '6uxYfENm7zw050dNUi031W',
#     'is_local': False,
#     'name': 'The Edge Of Glory',
#     'popularity': 45,
#     'preview_url': None,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:6uxYfENm7zw050dNUi031W'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 905}}

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#    'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#    'id': '6rePArBMb5nLWEaY9aQqL4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-11-05',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 294573,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70918596'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#   'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#   'id': '0SiywuOBRcynK0uKGWdCnn',
#   'is_local': False,
#   'name': 'Bad Romance',
#   'popularity': 82,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#    'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#    'id': '4jox3ip1I39DFC2B7R5qLH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba',
#      'width': 64}],
#    'name': 'GÉNESIS',
#    'release_date': '2023-06-29',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#     'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#     'id': '12GqGscKJx3aE4t07u7eVZ',
#     'name': 'Peso Pluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#     'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#     'id': '6Sbl0NT50roqWvy746MfVf',
#     'name': 'Gabito Ballesteros',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#     'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#     'id': '7Gi6gjaWy3DxyilpF1a8Is',
#     'name': 'Junior H',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 212878,
#   'explicit': True,
#   'external_ids': {'isrc': 'QM7282306246'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#   'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#   'id': '7mXuWTczZNxG5EDcjFEuJR',
#   'is_local': False,
#   'name': 'LADY GAGA',
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ec439edcef8f1b71e88cfeb7d200db274901123b?cid=5eae08977034419ebdafa2f6e0efa6b7',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#    'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#    'id': '1jpUMnKpRlng1OJN7LJauV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273631810af03785dbad83f5c81',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02631810af03785dbad83f5c81',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851631810af03785dbad83f5c81',
#      'width': 64}],
#    'name': 'The Fame',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 237200,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70824409'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5R8dQOPq8haW94K7mgERlO'},
#   'href': 'https://api.spotify.com/v1/tracks/5R8dQOPq8haW94K7mgERlO',
#   'id': '5R8dQOPq8haW94K7mgERlO',
#   'is_local': False,
#   'name': 'Poker Face',
#   'popularity': 76,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5R8dQOPq8haW94K7mgERlO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#    'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#    'id': '3edjzMAVB9RYRd4UcZBchx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 210200,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71813195'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2rbDhOo9Fh61Bbu23T2qCk'},
#   'href': 'https://api.spotify.com/v1/tracks/2rbDhOo9Fh61Bbu23T2qCk',
#   'id': '2rbDhOo9Fh61Bbu23T2qCk',
#   'is_local': False,
#   'name': 'Always Remember Us This Way',
#   'popularity': 81,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#    'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#    'id': '2KkMVsxymoNR7hRmBcMttd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#      'width': 64}],
#    'name': 'Born This Way',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 249066,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71104998'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0QkWikH5Z3U0f79T9iuF6c'},
#   'href': 'https://api.spotify.com/v1/tracks/0QkWikH5Z3U0f79T9iuF6c',
#   'id': '0QkWikH5Z3U0f79T9iuF6c',
#   'is_local': False,
#   'name': 'Judas',
#   'popularity': 71,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0QkWikH5Z3U0f79T9iuF6c'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#    'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#    'id': '1jpUMnKpRlng1OJN7LJauV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273631810af03785dbad83f5c81',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02631810af03785dbad83f5c81',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851631810af03785dbad83f5c81',
#      'width': 64}],
#    'name': 'The Fame',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#     'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#     'id': '7fObcBw9VM3x7ntWKCYl0z',
#     'name': "Colby O'Donis",
#     'type': 'artist',
#     'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 241933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70807646'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2x7MyWybabEz6Y6wvHuwGE'},
#   'href': 'https://api.spotify.com/v1/tracks/2x7MyWybabEz6Y6wvHuwGE',
#   'id': '2x7MyWybabEz6Y6wvHuwGE',
#   'is_local': False,
#   'name': 'Just Dance',
#   'popularity': 74,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2x7MyWybabEz6Y6wvHuwGE'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'MY',
#     'MT',
#     'MX',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DGZdMi124iOOih9GMlhN2'},
#    'href': 'https://api.spotify.com/v1/albums/6DGZdMi124iOOih9GMlhN2',
#    'id': '6DGZdMi124iOOih9GMlhN2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bfd247438980173d32fd5ba8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bfd247438980173d32fd5ba8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bfd247438980173d32fd5ba8',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-08-05',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:6DGZdMi124iOOih9GMlhN2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'MY',
#    'MT',
#    'MX',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 274213,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70905526'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4lwavw59UjXUPJZtKNdFYp'},
#   'href': 'https://api.spotify.com/v1/tracks/4lwavw59UjXUPJZtKNdFYp',
#   'id': '4lwavw59UjXUPJZtKNdFYp',
#   'is_local': False,
#   'name': 'Alejandro',
#   'popularity': 70,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4lwavw59UjXUPJZtKNdFYp'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#    'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#    'id': '5maeycU97NHBgwRr2h2A4O',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#      'width': 64}],
#    'name': 'Born This Way (Special Edition)',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 244760,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106449'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/11BKm0j4eYoCPPpCONAVwA'},
#   'href': 'https://api.spotify.com/v1/tracks/11BKm0j4eYoCPPpCONAVwA',
#   'id': '11BKm0j4eYoCPPpCONAVwA',
#   'is_local': False,
#   'name': 'Bloody Mary',
#   'popularity': 67,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:11BKm0j4eYoCPPpCONAVwA'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#    'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#    'id': '2KkMVsxymoNR7hRmBcMttd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#      'width': 64}],
#    'name': 'Born This Way',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 320586,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106458'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0JNdS1n0ifOP25XvhwAMgM'},
#   'href': 'https://api.spotify.com/v1/tracks/0JNdS1n0ifOP25XvhwAMgM',
#   'id': '0JNdS1n0ifOP25XvhwAMgM',
#   'is_local': False,
#   'name': 'The Edge Of Glory',
#   'popularity': 62,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:0JNdS1n0ifOP25XvhwAMgM'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#    'href': 'https://api.spotify.com/v1/albums/4sLtOBOzn4s3GDUv3c5oJD',
#    'id': '4sLtOBOzn4s3GDUv3c5oJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e2d156fdc691f57900134342',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e2d156fdc691f57900134342',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e2d156fdc691f57900134342',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 34,
#    'type': 'album',
#    'uri': 'spotify:album:4sLtOBOzn4s3GDUv3c5oJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'RW',
#    'TG',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 215733,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71813192'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2VxeLyX666F8uXCJ0dZF8B'},
#   'href': 'https://api.spotify.com/v1/tracks/2VxeLyX666F8uXCJ0dZF8B',
#   'id': '2VxeLyX666F8uXCJ0dZF8B',
#   'is_local': False,
#   'name': 'Shallow',
#   'popularity': 82,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:2VxeLyX666F8uXCJ0dZF8B'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3VQKj1DcT7bGsQGBZWBbE4'},
#      'href': 'https://api.spotify.com/v1/artists/3VQKj1DcT7bGsQGBZWBbE4',
#      'id': '3VQKj1DcT7bGsQGBZWBbE4',
#      'name': 'Grupo Viada',
#      'type': 'artist',
#      'uri': 'spotify:artist:3VQKj1DcT7bGsQGBZWBbE4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
# ...
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 2,
#   'duration_ms': 263360,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70824407'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1o716Hgxa1s7yWCXxy8saX'},
#   'href': 'https://api.spotify.com/v1/tracks/1o716Hgxa1s7yWCXxy8saX',
#   'id': '1o716Hgxa1s7yWCXxy8saX',
#   'is_local': False,
#   'name': 'Paper Gangsta',
#   'popularity': 42,
#   'preview_url': None,
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:1o716Hgxa1s7yWCXxy8saX'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#    'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#    'id': '3edjzMAVB9RYRd4UcZBchx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 217212,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71815945'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6QfS2wq5sSC1xAJCQsTSlj'},
#   'href': 'https://api.spotify.com/v1/tracks/6QfS2wq5sSC1xAJCQsTSlj',
#   'id': '6QfS2wq5sSC1xAJCQsTSlj',
#   'is_local': False,
#   'name': 'Shallow - Radio Edit',
#   'popularity': 68,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:6QfS2wq5sSC1xAJCQsTSlj'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#    'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#    'id': '3edjzMAVB9RYRd4UcZBchx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 202640,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71813201'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4gdfWGyzB9j4ZVc2JWdpv2'},
#   'href': 'https://api.spotify.com/v1/tracks/4gdfWGyzB9j4ZVc2JWdpv2',
#   'id': '4gdfWGyzB9j4ZVc2JWdpv2',
#   'is_local': False,
#   'name': 'Hair Body Face',
#   'popularity': 47,
#   'preview_url': None,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:4gdfWGyzB9j4ZVc2JWdpv2'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#    'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#    'id': '5maeycU97NHBgwRr2h2A4O',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#      'width': 64}],
#    'name': 'Born This Way (Special Edition)',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 320546,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106458'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6uxYfENm7zw050dNUi031W'},
#   'href': 'https://api.spotify.com/v1/tracks/6uxYfENm7zw050dNUi031W',
#   'id': '6uxYfENm7zw050dNUi031W',
#   'is_local': False,
#   'name': 'The Edge Of Glory',
#   'popularity': 45,
#   'preview_url': None,
#   'track_number': 17,
#   'type': 'track',
#   'uri': 'spotify:track:6uxYfENm7zw050dNUi031W'}]

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 905

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#   'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#   'id': '6rePArBMb5nLWEaY9aQqL4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#     'width': 64}],
#   'name': 'The Fame Monster (Deluxe Edition)',
#   'release_date': '2009-11-05',
#   'release_date_precision': 'day',
#   'total_tracks': 23,
#   'type': 'album',
#   'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 294573,
#  'explicit': True,
#  'external_ids': {'isrc': 'USUM70918596'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#  'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#  'id': '0SiywuOBRcynK0uKGWdCnn',
#  'is_local': False,
#  'name': 'Bad Romance',
#  'popularity': 82,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'}

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '0SiywuOBRcynK0uKGWdCnn'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 82

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %% [markdown]
# def get_top_tracks(artist_name):
#     # Dummy data for demonstration
#     if artist_name == "Los Fabulosos Cadillacs":
#         return ["Matador", "Vasos Vacíos", "Mal Bicho", "Siguiendo la Luna", "El Genio del Dub"]
#     elif artist_name == "Manu Chao":
#         return ["Me Gustas Tú", "Bongo Bong", "Clandestino", "Desaparecido", "La Vida Tómbola"]
#     elif artist_name == "Muchachito Bombo Infierno":
#         return ["Visto lo Visto", "Ojalá Estuvieras Muerto", "La Quema", "Soy Caminante", "Paquito Tarantino"]
#     else:
#         return []

# %%
get_top_tracks('Los Fabulosos Cadillacs')
# Out:
# ['Matador',
#  'Vasos Vacíos',
#  'Mal Bicho',
#  'Siguiendo la Luna',
#  'El Genio del Dub']

# %% [markdown]
# def get_artist_id(artist_name):
#     result = sp.search(q=artist_name, limit=1, type='artist')
#     if result['artists']['items']:
#         return result['artists']['items'][0]['id']
#     else:
#         return None

# %%
artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]
get_artist_id('Los Fabulosos Cadillacs')
# Out:
# '2FS22haX3FYbyOsUAkuYqZ'

# %% [markdown]
# def find_related_artists_list(artist_names_list):
#     related_artists_list = []
#     for artist_name in artist_names_list:
#         artist_id = get_artist_id(artist_name)
#         if artist_id:
#             related_artists = sp.artist_related_artists(artist_id)['artists']
#             related_artists_list.append([artist['name'] for artist in related_artists][:5])
#         else:
#             related_artists_list.append([])
#     return related_artists_list

# %%
find_related_artists_list(["Manu Chao"])
# Out:
# [['Mano Negra',
#   'Buena Vista Social Club',
#   'Orishas',
#   'Onda Vaga',
#   'Todos Tus Muertos']]

# %%
find_related_artists_list(["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"])
# Out:
# [['Los Auténticos Decadentes',
#   'Los Pericos',
#   'Vicentico',
#   'Maldita Vecindad Y Los Hijos Del 5to. Patio',
#   'Aterciopelados'],
#  ['Mano Negra',
#   'Buena Vista Social Club',
#   'Orishas',
#   'Onda Vaga',
#   'Todos Tus Muertos'],
#  ['Canteca de macao',
#   'La Cabra Mecanica',
#   'Tomasito',
#   'El Puchero Del Hortelano',
#   'Amparanoia']]

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'De 50 populairste hits van nu. Cover: Shaboozey',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSBi5svWQ9Nk'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSBi5svWQ9Nk',
#     'id': '37i9dQZF1DWSBi5svWQ9Nk',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002b1e9dfd274fc41e2bcdf3c20',
#       'width': None}],
#     'name': 'Hot Hits NL',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#C3F0C8',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAABRZCB5u/UBnPgQkS3/oLNo',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSBi5svWQ9Nk/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWSBi5svWQ9Nk'},
#    {'collaborative': False,
#     'description': 'De grootste hits uit de kroeg in één playlist.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUppGmuwT9c7'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUppGmuwT9c7',
#     'id': '37i9dQZF1DWUppGmuwT9c7',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c5bc867c614c646346196d5d',
#       'width': None}],
#     'name': 'Kroegenhits 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAABiDMq82FdsxTq/0mn7ux/C',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUppGmuwT9c7/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWUppGmuwT9c7'},
#    {'collaborative': False,
#     'description': 'De beste Nederlandse liedjes. Cover: Roxy Dekker',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdKMCnEhDnDL'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdKMCnEhDnDL',
#     'id': '37i9dQZF1DXdKMCnEhDnDL',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002ffe25a7416b20dcaaebf21c1',
#       'width': None}],
#     'name': 'Beste van NL',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zoa31gAAAACmB1z2AF/qyykXNaKZT2rU',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdKMCnEhDnDL/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXdKMCnEhDnDL'},
#    {'collaborative': False,
#     'description': 'All the songs from the new setlist for Taylor Swift | The Eras Tour.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0D996ZXujBy'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0D996ZXujBy',
#     'id': '37i9dQZF1DX0D996ZXujBy',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000211dcd47142c38c7c1ab47b0e',
#       'width': None}],
#     'name': 'Taylor Swift | The Eras Tour Official Setlist',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zj4OYAAAAADCbEBH/Hi8CdKVNmtDEV4A',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0D996ZXujBy/tracks',
#      'total': 44},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0D996ZXujBy'},
#    {'collaborative': False,
#     'description': 'The summer needs dance hits 😎☀️',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZ7eJRBxKzdO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO',
#     'id': '37i9dQZF1DWZ7eJRBxKzdO',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c7ea8e62ee86671eaa4c341c',
#       'width': None}],
#     'name': 'Summer Dance Hits 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZnyG+QAAAACm+t+LHylRaIj2MoGRDGtR',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO/tracks',
#      'total': 120},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWZ7eJRBxKzdO'},
#    {'collaborative': False,
#     'description': 'De zomer van 2024 beleef je hier!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcx1szy2g67M'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcx1szy2g67M',
#     'id': '37i9dQZF1DXcx1szy2g67M',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027fd229e89bf41454017f83f2',
#       'width': None}],
#     'name': 'Summer 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAADK2mnutptzMLbok0CjPaI+',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcx1szy2g67M/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcx1szy2g67M'},
#    {'collaborative': False,
#     'description': 'Nieuw: Fatah, Lijpe, Lusho, Geechi, Jordymone9 en meer',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX19xRtMyA5LM'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX19xRtMyA5LM',
#     'id': '37i9dQZF1DX19xRtMyA5LM',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000029363942e852bbaf754242045',
#       'width': None}],
#     'name': 'Woordenschat',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAAC5Ukit97gs9r1BBCZMyyzX',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX19xRtMyA5LM/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX19xRtMyA5LM'},
#    {'collaborative': False,
#     'description': 'De nieuwste releases elke vrijdag op Spotify! Cover: Davina Michelle',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXb5BKLTO7ULa'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb5BKLTO7ULa',
#     'id': '37i9dQZF1DXb5BKLTO7ULa',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002066498e3677cd1e91b093a64',
#       'width': None}],
#     'name': 'New Music Friday NL',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#A0C3D2',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAAAReQ+uLCKkd8QtyU3PNbq2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb5BKLTO7ULa/tracks',
#      'total': 90},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXb5BKLTO7ULa'},
#    {'collaborative': False,
#     'description': 'Billie Eilish is on top of the Hottest 50!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000292d0daa33844b0c6327d3a64',
#       'width': None}],
#     'name': 'Today’s Top Hits',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZodvwAAAAAAkFAj+3g1WhM7aKL8/rLfU',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'},
#    {'collaborative': False,
#     'description': 'The essential tracks, all in one playlist.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5KpP2LN299J'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5KpP2LN299J',
#     'id': '37i9dQZF1DX5KpP2LN299J',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000252feef11af8c9d412769ec5a',
#       'width': None}],
#     'name': 'This Is Taylor Swift',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'Zn45agAAAACbDgJsfXK07qnFayq1FWBu',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5KpP2LN299J/tracks',
#      'total': 180},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5KpP2LN299J'},
#    {'collaborative': False,
#     'description': 'Volks | levenslied | Hollands | Nederlandstalige pop. Cover: Django Wagner',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTS9w7exPdXE'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTS9w7exPdXE',
#     'id': '37i9dQZF1DWTS9w7exPdXE',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000028251c8412ccb783d122b5edb',
#       'width': None}],
#     'name': 'Hollandse Meezingers',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZmMIlwAAAADPkypwPQ2nWCaKr3DZGHj7',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTS9w7exPdXE/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTS9w7exPdXE'},
#    {'collaborative': False,
#     'description': 'Koffie met gemoedelijke muziek op de achtergrond.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYPwGkJoztcR'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYPwGkJoztcR',
#     'id': '37i9dQZF1DWYPwGkJoztcR',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002ccd92cc647bb6b0b45cc0662',
#       'width': None}],
#     'name': "'t Koffiehuis",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zn3g4AAAAADTgwhBiV4WybpETh01Bf2C',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYPwGkJoztcR/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWYPwGkJoztcR'},
#    {'collaborative': False,
#     'description': 'Motion en good vibes. Cover: Hakmadafack',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXHyhanaNMoy'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXHyhanaNMoy',
#     'id': '37i9dQZF1DWXHyhanaNMoy',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002fb3d2d685fda73d3541d7005',
#       'width': None}],
#     'name': 'La Vida Loca',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ec1e32',
#     'public': True,
#     'snapshot_id': 'ZoedYQAAAADtfm8c1S8gcXaBIHgn2KRn',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXHyhanaNMoy/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWXHyhanaNMoy'},
#    {'collaborative': False,
#     'description': 'Afro, Caribbean & Latin sounds for that summer vibe',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVLVzn60NyuA'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVLVzn60NyuA',
#     'id': '37i9dQZF1DWVLVzn60NyuA',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002ea311d4169edb7caf7f208be',
#       'width': None}],
#     'name': 'Summer Vibes',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAABu48kPsbxMBVUDx9mnXR2x',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVLVzn60NyuA/tracks',
#      'total': 150},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWVLVzn60NyuA'},
#    {'collaborative': False,
#     'description': 'Get ready for Ibiza season 2024. See you on the dancefloor.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaCACvgOVs5K'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaCACvgOVs5K',
#     'id': '37i9dQZF1DXaCACvgOVs5K',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002ed6e941de6272373e82ea5ad',
#       'width': None}],
#     'name': 'Ibiza 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zoc3vAAAAABcSFoXrUbuqtGAhJ0sO7Hv',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaCACvgOVs5K/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXaCACvgOVs5K'},
#    {'collaborative': False,
#     'description': 'songs voor je playlist! #fyp',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7br4y32b7L8'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7br4y32b7L8',
#     'id': '37i9dQZF1DX7br4y32b7L8',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026a15d8841c697e05221103f5',
#       'width': None}],
#     'name': 'Viral Hits NL',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zoq08AAAAACanUijr8qIT7vKlPjVWrsD',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7br4y32b7L8/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX7br4y32b7L8'},
#    {'collaborative': False,
#     'description': 'De nieuwste Hollandse hits. Cover: André Hazes & Mart Hoogkamer',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3fVDvRBemdr'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3fVDvRBemdr',
#     'id': '37i9dQZF1DX3fVDvRBemdr',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000293608812b48e6c3eb4d8e76d',
#       'width': None}],
#     'name': 'Liever Hollands',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAAD9YGieIIefSBXhS2hXV4Ny',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3fVDvRBemdr/tracks',
#      'total': 75},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3fVDvRBemdr'},
#    {'collaborative': False,
#     'description': 'De beste en nieuwste dance hits. Cover: Tiësto, Dimitri Vegas & Like Mike en Gabry Ponte',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTwCImwcYjDL'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTwCImwcYjDL',
#     'id': '37i9dQZF1DWTwCImwcYjDL',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000263825e23fd7f7973f564a219',
#       'width': None}],
#     'name': '360 Dance',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZocbYAAAAADShDN/rk4uuw/pW8z3h55f',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTwCImwcYjDL/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTwCImwcYjDL'},
#    {'collaborative': False,
#     'description': 'Peaceful piano to help you slow down, breathe, and relax. ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#     'id': '37i9dQZF1DX4sWSpwq3LiO',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000283da657fca565320e9311863',
#       'width': None}],
#     'name': 'Peaceful Piano',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZmBBjgAAAAD0/y1AUqA0h6nT9YGniJTN',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO/tracks',
#      'total': 200},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'},
#    {'collaborative': False,
#     'description': 'Only the biggest Hardstyle tracks!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0pH2SQMRXnC'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0pH2SQMRXnC',
#     'id': '37i9dQZF1DX0pH2SQMRXnC',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002e77ad210ce47f7c6eb8796f9',
#       'width': None}],
#     'name': 'Hardstyle Bangers',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZoejuwAAAABEfYV5JgsCxe8xWkGf01ya',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0pH2SQMRXnC/tracks',
#      'total': 150},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0pH2SQMRXnC'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/featured-playlists?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# La Vie En Rose
# You Are My Sunshine
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# True Colours
# I'm Not the Only One - Live from Spotify, London
# Cold Heart - Acoustic
# September Song - Guitar Acoustic
# Collide - Acoustic Version
# Baby One More Time - Recorded at Spotify Studios New York City
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# When You Love Someone - Acoustic
# Rockabye - Acoustic Version
# Blinding Lights
# Ain't Nobody (Loves Me Better) - Acoustic
# Shape of You - Acoustic
# Little Talks
# Something Just Like This - Acoustic
# Linger
# Let It Go - James Bay Spotify Session 2015
# What About Us - Acoustic
# 1973 - Acoustic
# Heaven Is a Place on Earth
# Billie Jean
# Crazy in Love
# Perfect - Acoustic
# Wild Love - Acoustic
# Naked - Acoustic Version
# Firestone - Live Acoustic Version
# Can't Help Falling in Love
# Price Tag - Acoustic Version
# Fix You - Live
# Slow Dancing in a Burning Room - Acoustic
# Chasing Cars
# Summertime Sadness (Acoustic Cover) feat. Keelan Donovan
# We Can't Stop - Acoustic
# Dancing On My Own - Acoustic
# Halo
# Another Love - Live from Spotify (SXSW)
# Ordinary World
# All of Me - Live from Spotify Milan
# Kiss Me - AOL Sessions Acoustic Version
# Girls Just Wanna Have Fun - Acoustic
# Have You Ever Seen The Rain - Recorded at Electric Lady Studios NYC
# Hey Ya - solo version
# Bizarre Love Triangle - 2014 Remaster
# New Rules - Acoustic
# Landslide
# Mad World - Recorded at Metropolis Studios, London
# City of Stars
# It Aint me - Acoustic
# Bad Day - Acoustic
# Wild World - Acoustic Version
# IDGAF - Acoustic
# Don't Wanna Know - Acoustic Version
# Chandelier - Live from The Village
# Too Much To Ask - Acoustic
# I Kissed a Girl
# Pretty Girl - Acoustic Version
# Rhythm Inside - Acoustic
# Unchained Melody
# Sex On Fire
# When Doves Cry - Recorded At Spotify Studios NYC
# I Wanna Dance with Somebody
# U Remind Me - Recorded at Spotify Studios NYC
# Cold Water
# 2U - Acoustic Version
# Creep
# Over the Rainbow
# Umbrella - Acoustic Version
# Your Song - Acoustic
# I'm the One - Acoustic
# Stitches
# Sugar - Acoustic
# Brandy (You're a Fine Girl)
# Shallow
# Silence
# She's On My Mind - Guitar Acoustic
# Crazy - Live Sessions
# Please Keep Loving Me - Acoustic
# Stay
# How to Save a Life - Live in Nashville, TN - December 2006
# Starboy - Acoustic
# Dancing in the Moonlight - Acoustic Version
# Closer
# Scars To Your Beautiful
# Nervous - Acoustic
# Shut up and Dance
# Send My Love (To Your New Lover) - Live
# Once In a While - Acoustic
# Maps
# Lot To Learn
# XO
# Perfect Strangers - Acoustic
# New Rules
# There's Nothing Holdin Me Back
# Thunder
# Hello
# High and Dry

# %%
tracks
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5qDjtBY8cC4bO6wytuGOuT',
#      'id': '5qDjtBY8cC4bO6wytuGOuT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c6c1ca8d317e97873de0cbeb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c6c1ca8d317e97873de0cbeb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c6c1ca8d317e97873de0cbeb',
#        'width': 64}],
#      'name': 'Take Me Home, Country Roads',
#      'release_date': '2023-12-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5qDjtBY8cC4bO6wytuGOuT',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#        'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#        'id': '00FQb4jTyendYWaN8pK0wa',
#        'name': 'Lana Del Rey',
#        'type': 'artist',
#        'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qDjtBY8cC4bO6wytuGOuT'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#       'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#       'id': '00FQb4jTyendYWaN8pK0wa',
#       'name': 'Lana Del Rey',
#       'type': 'artist',
#       'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 166676,
#     'external_ids': {'isrc': 'GBUM72305740'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qF0FfuzBFwMe1lNHkEDxW'},
#     'href': 'https://api.spotify.com/v1/tracks/7qF0FfuzBFwMe1lNHkEDxW',
#     'id': '7qF0FfuzBFwMe1lNHkEDxW',
#     'name': 'Take Me Home, Country Roads',
#     'popularity': 68,
#     'uri': 'spotify:track:7qF0FfuzBFwMe1lNHkEDxW',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/250acd22ee4c3c1cb316d036e11f44b7404b46b3?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3rU947MaPxzKjSSbx4cQjg',
#      'id': '3rU947MaPxzKjSSbx4cQjg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273062f859ffcba42823f00c6c0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02062f859ffcba42823f00c6c0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851062f859ffcba42823f00c6c0',
#        'width': 64}],
#      'name': 'La Vie En Rose',
#      'release_date': '2015-01-28',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3rU947MaPxzKjSSbx4cQjg',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WfaItAbs4vlgIA1cuqGtJ'},
#        'href': 'https://api.spotify.com/v1/artists/0WfaItAbs4vlgIA1cuqGtJ',
#        'id': '0WfaItAbs4vlgIA1cuqGtJ',
#        'name': 'Daniela Andrade',
#        'type': 'artist',
#        'uri': 'spotify:artist:0WfaItAbs4vlgIA1cuqGtJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3rU947MaPxzKjSSbx4cQjg'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WfaItAbs4vlgIA1cuqGtJ'},
#       'href': 'https://api.spotify.com/v1/artists/0WfaItAbs4vlgIA1cuqGtJ',
#       'id': '0WfaItAbs4vlgIA1cuqGtJ',
#       'name': 'Daniela Andrade',
#       'type': 'artist',
#       'uri': 'spotify:artist:0WfaItAbs4vlgIA1cuqGtJ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 105500,
#     'external_ids': {'isrc': 'TCACD1552971'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0VxocBntP1XTZRsR9ZURPS'},
#     'href': 'https://api.spotify.com/v1/tracks/0VxocBntP1XTZRsR9ZURPS',
#     'id': '0VxocBntP1XTZRsR9ZURPS',
#     'name': 'La Vie En Rose',
#     'popularity': 61,
#     'uri': 'spotify:track:0VxocBntP1XTZRsR9ZURPS',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/db85e568e3544180887f4ced19e867a1cc0d77f7?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5ueNN8xbGK6BMFnLjeiXUM',
#      'id': '5ueNN8xbGK6BMFnLjeiXUM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c9241a6252536c81b46ff27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c9241a6252536c81b46ff27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c9241a6252536c81b46ff27',
#        'width': 64}],
#      'name': 'You Are My Sunshine',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5ueNN8xbGK6BMFnLjeiXUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TL8gYTNgD6nXkyuUdDrMg'},
#        'href': 'https://api.spotify.com/v1/artists/2TL8gYTNgD6nXkyuUdDrMg',
#        'id': '2TL8gYTNgD6nXkyuUdDrMg',
#        'name': 'Jasmine Thompson',
#        'type': 'artist',
#        'uri': 'spotify:artist:2TL8gYTNgD6nXkyuUdDrMg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ueNN8xbGK6BMFnLjeiXUM'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TL8gYTNgD6nXkyuUdDrMg'},
#       'href': 'https://api.spotify.com/v1/artists/2TL8gYTNgD6nXkyuUdDrMg',
#       'id': '2TL8gYTNgD6nXkyuUdDrMg',
#       'name': 'Jasmine Thompson',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TL8gYTNgD6nXkyuUdDrMg'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 157868,
#     'external_ids': {'isrc': 'USAT21603480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5qMjtrGnezsafpH4oqg7oU'},
#     'href': 'https://api.spotify.com/v1/tracks/5qMjtrGnezsafpH4oqg7oU',
#     'id': '5qMjtrGnezsafpH4oqg7oU',
#     'name': 'You Are My Sunshine',
#     'popularity': 61,
#     'uri': 'spotify:track:5qMjtrGnezsafpH4oqg7oU',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0BCjGDBIymcwf4etd4KBgu',
#      'id': '0BCjGDBIymcwf4etd4KBgu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bcd15fcddc56150530087816',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bcd15fcddc56150530087816',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bcd15fcddc56150530087816',
#        'width': 64}],
#      'name': '1.22.03 Acoustic',
#      'release_date': '2004',
#      'release_date_precision': 'year',
#      'uri': 'spotify:album:0BCjGDBIymcwf4etd4KBgu',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#        'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#        'id': '04gDigrS5kc9YWfZHwBETP',
#        'name': 'Maroon 5',
#        'type': 'artist',
#        'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BCjGDBIymcwf4etd4KBgu'},
#      'total_tracks': 7},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#       'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#       'id': '04gDigrS5kc9YWfZHwBETP',
#       'name': 'Maroon 5',
#       'type': 'artist',
#       'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 254853,
#     'external_ids': {'isrc': 'USJAY0400210'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3bXhtg6H8lOMWaLZttQF6F'},
#     'href': 'https://api.spotify.com/v1/tracks/3bXhtg6H8lOMWaLZttQF6F',
#     'id': '3bXhtg6H8lOMWaLZttQF6F',
#     'name': 'Sunday Morning - Acoustic',
#     'popularity': 60,
#     'uri': 'spotify:track:3bXhtg6H8lOMWaLZttQF6F',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/33wYkcgcs44wHh8QCO6G7p',
#      'id': '33wYkcgcs44wHh8QCO6G7p',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af98f1682f6f24447bda6132',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af98f1682f6f24447bda6132',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af98f1682f6f24447bda6132',
#        'width': 64}],
#      'name': 'Too Good At Goodbyes (Acoustic)',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:33wYkcgcs44wHh8QCO6G7p',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33wYkcgcs44wHh8QCO6G7p'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 220095,
#     'external_ids': {'isrc': 'GBUM71704061'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1JhuXhMiTBavuRXQTsGOdV'},
#     'href': 'https://api.spotify.com/v1/tracks/1JhuXhMiTBavuRXQTsGOdV',
#     'id': '1JhuXhMiTBavuRXQTsGOdV',
#     'name': 'Too Good At Goodbyes - Acoustic',
#     'popularity': 60,
#     'uri': 'spotify:track:1JhuXhMiTBavuRXQTsGOdV',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/f946a5228b18c3f97c7686e0c9ed31834c74f33c?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2KYcp0bkKyyGllYygfdtHX',
#      'id': '2KYcp0bkKyyGllYygfdtHX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27375cf479508ef858fbf62d425',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0275cf479508ef858fbf62d425',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485175cf479508ef858fbf62d425',
#        'width': 64}],
#      'name': 'True Colours',
#      'release_date': '2016-09-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2KYcp0bkKyyGllYygfdtHX',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2txHhyCwHjUEpJjWrEyqyX'},
#        'href': 'https://api.spotify.com/v1/artists/2txHhyCwHjUEpJjWrEyqyX',
#        'id': '2txHhyCwHjUEpJjWrEyqyX',
#        'name': 'Tom Odell',
#        'type': 'artist',
#        'uri': 'spotify:artist:2txHhyCwHjUEpJjWrEyqyX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KYcp0bkKyyGllYygfdtHX'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2txHhyCwHjUEpJjWrEyqyX'},
#       'href': 'https://api.spotify.com/v1/artists/2txHhyCwHjUEpJjWrEyqyX',
#       'id': '2txHhyCwHjUEpJjWrEyqyX',
#       'name': 'Tom Odell',
#       'type': 'artist',
#       'uri': 'spotify:artist:2txHhyCwHjUEpJjWrEyqyX'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 143706,
#     'external_ids': {'isrc': 'GBARL1601064'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1rGxG6Y5OgmSwGPRPJv9Q4'},
#     'href': 'https://api.spotify.com/v1/tracks/1rGxG6Y5OgmSwGPRPJv9Q4',
#     'id': '1rGxG6Y5OgmSwGPRPJv9Q4',
#     'name': 'True Colours',
#     'popularity': 60,
#     'uri': 'spotify:track:1rGxG6Y5OgmSwGPRPJv9Q4',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/8fab79ca3b096c4b36549ecba8344ddd6a3a6faa?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3NW16XZ8U99Qm8E9v52UTz',
#      'id': '3NW16XZ8U99Qm8E9v52UTz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27387adc6b4dafc57c8524d519a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0287adc6b4dafc57c8524d519a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485187adc6b4dafc57c8524d519a',
#        'width': 64}],
#      'name': 'Spotify Session',
#      'release_date': '2016-07-08',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3NW16XZ8U99Qm8E9v52UTz',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3NW16XZ8U99Qm8E9v52UTz'},
#      'total_tracks': 5},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 195840,
#     'external_ids': {'isrc': 'GBAHT1600296'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wIYDzWW82O6Rc4vGuzjND'},
#     'href': 'https://api.spotify.com/v1/tracks/7wIYDzWW82O6Rc4vGuzjND',
#     'id': '7wIYDzWW82O6Rc4vGuzjND',
#     'name': "I'm Not the Only One - Live from Spotify, London",
#     'popularity': 59,
#     'uri': 'spotify:track:7wIYDzWW82O6Rc4vGuzjND',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
# ...
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/0yCicHSIShiIcJLkpyxKIC',
#      'id': '0yCicHSIShiIcJLkpyxKIC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ee11da08f718e83653565c96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ee11da08f718e83653565c96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ee11da08f718e83653565c96',
#        'width': 64}],
#      'name': 'Thunder',
#      'release_date': '2021-05-14',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0yCicHSIShiIcJLkpyxKIC',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kU8z1cAsNbINQt3ZyFka8'},
#        'href': 'https://api.spotify.com/v1/artists/1kU8z1cAsNbINQt3ZyFka8',
#        'id': '1kU8z1cAsNbINQt3ZyFka8',
#        'name': 'The Freed',
#        'type': 'artist',
#        'uri': 'spotify:artist:1kU8z1cAsNbINQt3ZyFka8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0yCicHSIShiIcJLkpyxKIC'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kU8z1cAsNbINQt3ZyFka8'},
#       'href': 'https://api.spotify.com/v1/artists/1kU8z1cAsNbINQt3ZyFka8',
#       'id': '1kU8z1cAsNbINQt3ZyFka8',
#       'name': 'The Freed',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kU8z1cAsNbINQt3ZyFka8'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 204230,
#     'external_ids': {'isrc': 'SE5IB2113834'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0rRtQsqQAaS45dgHfd8t1l'},
#     'href': 'https://api.spotify.com/v1/tracks/0rRtQsqQAaS45dgHfd8t1l',
#     'id': '0rRtQsqQAaS45dgHfd8t1l',
#     'name': 'Thunder',
#     'popularity': 43,
#     'uri': 'spotify:track:0rRtQsqQAaS45dgHfd8t1l',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/954388a43db2edc372982ea41e4889237283d7d6?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/0A6U4HudXB9ZDv3y1Y44qW',
#      'id': '0A6U4HudXB9ZDv3y1Y44qW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273018355f025b716d245ec27d9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02018355f025b716d245ec27d9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851018355f025b716d245ec27d9',
#        'width': 64}],
#      'name': 'Hello (Adele Cover)',
#      'release_date': '2015-10-24',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0A6U4HudXB9ZDv3y1Y44qW',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72T7KgrFiMTgXRWxfuDn5o'},
#        'href': 'https://api.spotify.com/v1/artists/72T7KgrFiMTgXRWxfuDn5o',
#        'id': '72T7KgrFiMTgXRWxfuDn5o',
#        'name': 'Erato',
#        'type': 'artist',
#        'uri': 'spotify:artist:72T7KgrFiMTgXRWxfuDn5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0A6U4HudXB9ZDv3y1Y44qW'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72T7KgrFiMTgXRWxfuDn5o'},
#       'href': 'https://api.spotify.com/v1/artists/72T7KgrFiMTgXRWxfuDn5o',
#       'id': '72T7KgrFiMTgXRWxfuDn5o',
#       'name': 'Erato',
#       'type': 'artist',
#       'uri': 'spotify:artist:72T7KgrFiMTgXRWxfuDn5o'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 230225,
#     'external_ids': {'isrc': 'SEVJH1501901'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5mCLi8QdP2d9EoSIEoO8jX'},
#     'href': 'https://api.spotify.com/v1/tracks/5mCLi8QdP2d9EoSIEoO8jX',
#     'id': '5mCLi8QdP2d9EoSIEoO8jX',
#     'name': 'Hello',
#     'popularity': 42,
#     'uri': 'spotify:track:5mCLi8QdP2d9EoSIEoO8jX',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-11-30T18:27:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/20997e6ce8d23ba4e60050c910c73c8bd015b2d9?cid=5eae08977034419ebdafa2f6e0efa6b7',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'DJ',
#       'ZM',
#       'CG',
#       'TJ',
#       'VE',
#       'ET'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6O8BafrfHOLH6V2v3dsPV2',
#      'id': '6O8BafrfHOLH6V2v3dsPV2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736db3968e68c8fdbb5ae737a0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026db3968e68c8fdbb5ae737a0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516db3968e68c8fdbb5ae737a0',
#        'width': 64}],
#      'name': 'High and Dry',
#      'release_date': '2016-04-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6O8BafrfHOLH6V2v3dsPV2',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Y4125mDrgQyPD7dt76Rtm'},
#        'href': 'https://api.spotify.com/v1/artists/2Y4125mDrgQyPD7dt76Rtm',
#        'id': '2Y4125mDrgQyPD7dt76Rtm',
#        'name': 'Colin & Caroline',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Y4125mDrgQyPD7dt76Rtm'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6O8BafrfHOLH6V2v3dsPV2'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Y4125mDrgQyPD7dt76Rtm'},
#       'href': 'https://api.spotify.com/v1/artists/2Y4125mDrgQyPD7dt76Rtm',
#       'id': '2Y4125mDrgQyPD7dt76Rtm',
#       'name': 'Colin & Caroline',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Y4125mDrgQyPD7dt76Rtm'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 249752,
#     'external_ids': {'isrc': 'TCACN1638327'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5jUExRL4pCNDYPz9qzzK2F'},
#     'href': 'https://api.spotify.com/v1/tracks/5jUExRL4pCNDYPz9qzzK2F',
#     'id': '5jUExRL4pCNDYPz9qzzK2F',
#     'name': 'High and Dry',
#     'popularity': 42,
#     'uri': 'spotify:track:5jUExRL4pCNDYPz9qzzK2F',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 150}

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Daniela Andrade', 'Jasmine Thompson', 'Maroon 5', 'Sam Smith', 'Tom Odell', 'Dua Lipa', 'Elton John', 'JP Cooper', 'Howie Day', 'Ed Sheeran', 'James Bay', 'James TW', 'The Mayries', 'Ouvindo', 'Julia Sheer', 'Jon D', 'Missy & Blonde', 'Julia Ross', 'Freedom Fry', 'Thomas Daniel', 'James Blunt', 'The Civil Wars', 'James Arthur', 'Kygo', 'Conrad Sewell', 'Kacey Musgraves', 'Jessie J', 'John Mayer', 'The Wind and The Wave', 'Megan Davies', 'Keelan Donovan', 'Halloran & Kate', 'Calum Scott', 'Lotte Kestner', 'Joy Williams', 'John Legend', 'Sixpence None The Richer', 'The Lumineers', 'Obadiah Parker', 'Frente!', 'Molly Parden', 'Hollow Hum', 'Lily Allen', 'Gavin James', 'Sara Farell', 'Daniel Powter', 'Joanna Wang', 'Sia', 'Niall Horan', 'William Fitzsimmons', 'Becca Adams', 'Lykke Li', 'Alex Cornell', 'Sarah Jarosz', 'Rachel Brown', 'Kyle Nachtigal', 'Clementine Duo', 'Arlo Parks', "Israel Kamakawiwo'ole", 'Rita Ora', 'Sunset & Highland', 'Jaclyn Davies', 'Francesco Yates', 'Catey Shaw', 'The Hound + The Fox', 'Reggii', 'Madilyn Bailey', 'Leroy Sanchez', 'Isabella Celander', 'The Fray', 'Simon Samaeng', 'Toploader', 'Tore', 'Anchor + Bell', "I'm With Her", 'Paul Kowert', 'Timeflies', 'Colin & Caroline', 'Vivid Color', 'Anna Elizabeth Laube', 'Jonas Blue', 'Q.Z.B', 'The Freed', 'Erato']

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %% [markdown]
# Ex.2.1: Extracting and displaying the names and IDs of the top 5 featured playlists.

# %%
featured_playlists = sp.featured_playlists()['playlists']['items']

# %%
featured_playlists
# Out:
# [{'collaborative': False,
#   'description': 'De 50 populairste hits van nu. Cover: Shaboozey',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSBi5svWQ9Nk'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSBi5svWQ9Nk',
#   'id': '37i9dQZF1DWSBi5svWQ9Nk',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002b1e9dfd274fc41e2bcdf3c20',
#     'width': None}],
#   'name': 'Hot Hits NL',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#C3F0C8',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAABRZCB5u/UBnPgQkS3/oLNo',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSBi5svWQ9Nk/tracks',
#    'total': 50},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWSBi5svWQ9Nk'},
#  {'collaborative': False,
#   'description': 'De grootste hits uit de kroeg in één playlist.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUppGmuwT9c7'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUppGmuwT9c7',
#   'id': '37i9dQZF1DWUppGmuwT9c7',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002c5bc867c614c646346196d5d',
#     'width': None}],
#   'name': 'Kroegenhits 2024',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAABiDMq82FdsxTq/0mn7ux/C',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUppGmuwT9c7/tracks',
#    'total': 80},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWUppGmuwT9c7'},
#  {'collaborative': False,
#   'description': 'De beste Nederlandse liedjes. Cover: Roxy Dekker',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdKMCnEhDnDL'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdKMCnEhDnDL',
#   'id': '37i9dQZF1DXdKMCnEhDnDL',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002ffe25a7416b20dcaaebf21c1',
#     'width': None}],
#   'name': 'Beste van NL',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'Zoa31gAAAACmB1z2AF/qyykXNaKZT2rU',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdKMCnEhDnDL/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXdKMCnEhDnDL'},
#  {'collaborative': False,
#   'description': 'All the songs from the new setlist for Taylor Swift | The Eras Tour.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0D996ZXujBy'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0D996ZXujBy',
#   'id': '37i9dQZF1DX0D996ZXujBy',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000211dcd47142c38c7c1ab47b0e',
#     'width': None}],
#   'name': 'Taylor Swift | The Eras Tour Official Setlist',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'Zj4OYAAAAADCbEBH/Hi8CdKVNmtDEV4A',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0D996ZXujBy/tracks',
#    'total': 44},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX0D996ZXujBy'},
#  {'collaborative': False,
#   'description': 'The summer needs dance hits 😎☀️',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZ7eJRBxKzdO'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO',
#   'id': '37i9dQZF1DWZ7eJRBxKzdO',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002c7ea8e62ee86671eaa4c341c',
#     'width': None}],
#   'name': 'Summer Dance Hits 2024',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZnyG+QAAAACm+t+LHylRaIj2MoGRDGtR',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO/tracks',
#    'total': 120},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWZ7eJRBxKzdO'},
#  {'collaborative': False,
#   'description': 'De zomer van 2024 beleef je hier!',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcx1szy2g67M'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcx1szy2g67M',
#   'id': '37i9dQZF1DXcx1szy2g67M',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000027fd229e89bf41454017f83f2',
#     'width': None}],
#   'name': 'Summer 2024',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAADK2mnutptzMLbok0CjPaI+',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcx1szy2g67M/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXcx1szy2g67M'},
#  {'collaborative': False,
#   'description': 'Nieuw: Fatah, Lijpe, Lusho, Geechi, Jordymone9 en meer',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX19xRtMyA5LM'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX19xRtMyA5LM',
#   'id': '37i9dQZF1DX19xRtMyA5LM',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000029363942e852bbaf754242045',
#     'width': None}],
#   'name': 'Woordenschat',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAAC5Ukit97gs9r1BBCZMyyzX',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX19xRtMyA5LM/tracks',
#    'total': 60},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX19xRtMyA5LM'},
#  {'collaborative': False,
#   'description': 'De nieuwste releases elke vrijdag op Spotify! Cover: Davina Michelle',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXb5BKLTO7ULa'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb5BKLTO7ULa',
#   'id': '37i9dQZF1DXb5BKLTO7ULa',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002066498e3677cd1e91b093a64',
#     'width': None}],
#   'name': 'New Music Friday NL',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#A0C3D2',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAAAReQ+uLCKkd8QtyU3PNbq2',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb5BKLTO7ULa/tracks',
#    'total': 90},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXb5BKLTO7ULa'},
#  {'collaborative': False,
#   'description': 'Billie Eilish is on top of the Hottest 50!',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#   'id': '37i9dQZF1DXcBWIGoYBM5M',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000292d0daa33844b0c6327d3a64',
#     'width': None}],
#   'name': 'Today’s Top Hits',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#FFFFFF',
#   'public': True,
#   'snapshot_id': 'ZodvwAAAAAAkFAj+3g1WhM7aKL8/rLfU',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#    'total': 50},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'},
#  {'collaborative': False,
#   'description': 'The essential tracks, all in one playlist.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5KpP2LN299J'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5KpP2LN299J',
#   'id': '37i9dQZF1DX5KpP2LN299J',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000252feef11af8c9d412769ec5a',
#     'width': None}],
#   'name': 'This Is Taylor Swift',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#FFFFFF',
#   'public': True,
#   'snapshot_id': 'Zn45agAAAACbDgJsfXK07qnFayq1FWBu',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5KpP2LN299J/tracks',
#    'total': 180},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX5KpP2LN299J'},
#  {'collaborative': False,
#   'description': 'Volks | levenslied | Hollands | Nederlandstalige pop. Cover: Django Wagner',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTS9w7exPdXE'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTS9w7exPdXE',
#   'id': '37i9dQZF1DWTS9w7exPdXE',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000028251c8412ccb783d122b5edb',
#     'width': None}],
#   'name': 'Hollandse Meezingers',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZmMIlwAAAADPkypwPQ2nWCaKr3DZGHj7',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTS9w7exPdXE/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWTS9w7exPdXE'},
#  {'collaborative': False,
#   'description': 'Koffie met gemoedelijke muziek op de achtergrond.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYPwGkJoztcR'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYPwGkJoztcR',
#   'id': '37i9dQZF1DWYPwGkJoztcR',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002ccd92cc647bb6b0b45cc0662',
#     'width': None}],
#   'name': "'t Koffiehuis",
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'Zn3g4AAAAADTgwhBiV4WybpETh01Bf2C',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYPwGkJoztcR/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWYPwGkJoztcR'},
#  {'collaborative': False,
#   'description': 'Motion en good vibes. Cover: Hakmadafack',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXHyhanaNMoy'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXHyhanaNMoy',
#   'id': '37i9dQZF1DWXHyhanaNMoy',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002fb3d2d685fda73d3541d7005',
#     'width': None}],
#   'name': 'La Vida Loca',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ec1e32',
#   'public': True,
#   'snapshot_id': 'ZoedYQAAAADtfm8c1S8gcXaBIHgn2KRn',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXHyhanaNMoy/tracks',
#    'total': 70},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWXHyhanaNMoy'},
#  {'collaborative': False,
#   'description': 'Afro, Caribbean & Latin sounds for that summer vibe',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVLVzn60NyuA'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVLVzn60NyuA',
#   'id': '37i9dQZF1DWVLVzn60NyuA',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002ea311d4169edb7caf7f208be',
#     'width': None}],
#   'name': 'Summer Vibes',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAABu48kPsbxMBVUDx9mnXR2x',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVLVzn60NyuA/tracks',
#    'total': 150},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWVLVzn60NyuA'},
#  {'collaborative': False,
#   'description': 'Get ready for Ibiza season 2024. See you on the dancefloor.',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaCACvgOVs5K'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaCACvgOVs5K',
#   'id': '37i9dQZF1DXaCACvgOVs5K',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002ed6e941de6272373e82ea5ad',
#     'width': None}],
#   'name': 'Ibiza 2024',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'Zoc3vAAAAABcSFoXrUbuqtGAhJ0sO7Hv',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaCACvgOVs5K/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DXaCACvgOVs5K'},
#  {'collaborative': False,
#   'description': 'songs voor je playlist! #fyp',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7br4y32b7L8'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7br4y32b7L8',
#   'id': '37i9dQZF1DX7br4y32b7L8',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f000000026a15d8841c697e05221103f5',
#     'width': None}],
#   'name': 'Viral Hits NL',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'Zoq08AAAAACanUijr8qIT7vKlPjVWrsD',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7br4y32b7L8/tracks',
#    'total': 80},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX7br4y32b7L8'},
#  {'collaborative': False,
#   'description': 'De nieuwste Hollandse hits. Cover: André Hazes & Mart Hoogkamer',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3fVDvRBemdr'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3fVDvRBemdr',
#   'id': '37i9dQZF1DX3fVDvRBemdr',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000293608812b48e6c3eb4d8e76d',
#     'width': None}],
#   'name': 'Liever Hollands',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAAD9YGieIIefSBXhS2hXV4Ny',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3fVDvRBemdr/tracks',
#    'total': 75},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX3fVDvRBemdr'},
#  {'collaborative': False,
#   'description': 'De beste en nieuwste dance hits. Cover: Tiësto, Dimitri Vegas & Like Mike en Gabry Ponte',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTwCImwcYjDL'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTwCImwcYjDL',
#   'id': '37i9dQZF1DWTwCImwcYjDL',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000263825e23fd7f7973f564a219',
#     'width': None}],
#   'name': '360 Dance',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZocbYAAAAADShDN/rk4uuw/pW8z3h55f',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTwCImwcYjDL/tracks',
#    'total': 50},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DWTwCImwcYjDL'},
#  {'collaborative': False,
#   'description': 'Peaceful piano to help you slow down, breathe, and relax. ',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO',
#   'id': '37i9dQZF1DX4sWSpwq3LiO',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f0000000283da657fca565320e9311863',
#     'width': None}],
#   'name': 'Peaceful Piano',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#ffffff',
#   'public': True,
#   'snapshot_id': 'ZmBBjgAAAAD0/y1AUqA0h6nT9YGniJTN',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4sWSpwq3LiO/tracks',
#    'total': 200},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX4sWSpwq3LiO'},
#  {'collaborative': False,
#   'description': 'Only the biggest Hardstyle tracks!',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0pH2SQMRXnC'},
#   'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0pH2SQMRXnC',
#   'id': '37i9dQZF1DX0pH2SQMRXnC',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706f00000002e77ad210ce47f7c6eb8796f9',
#     'width': None}],
#   'name': 'Hardstyle Bangers',
#   'owner': {'display_name': 'Spotify',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#    'href': 'https://api.spotify.com/v1/users/spotify',
#    'id': 'spotify',
#    'type': 'user',
#    'uri': 'spotify:user:spotify'},
#   'primary_color': '#FFFFFF',
#   'public': True,
#   'snapshot_id': 'ZoejuwAAAABEfYV5JgsCxe8xWkGf01ya',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0pH2SQMRXnC/tracks',
#    'total': 150},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:37i9dQZF1DX0pH2SQMRXnC'}]

# %%
top_featured_playlists = featured_playlists[:5]
print("Top 5 Featured Playlists:")
for i, playlist in enumerate(top_featured_playlists):
    print(f"{i + 1}. Name: {playlist['name']}, ID: {playlist['id']}")
# Out:
# Top 5 Featured Playlists:
# 1. Name: Hot Hits NL, ID: 37i9dQZF1DWSBi5svWQ9Nk
# 2. Name: Kroegenhits 2024, ID: 37i9dQZF1DWUppGmuwT9c7
# 3. Name: Beste van NL, ID: 37i9dQZF1DXdKMCnEhDnDL
# 4. Name: Taylor Swift | The Eras Tour Official Setlist, ID: 37i9dQZF1DX0D996ZXujBy
# 5. Name: Summer Dance Hits 2024, ID: 37i9dQZF1DWZ7eJRBxKzdO

# %%
featured_playlists = sp.featured_playlists(limit=5)
playlists = featured_playlists['playlists']['items']

# Display the names and IDs of the top 5 featured playlists
print("Top 5 Featured Playlists:")
for idx, playlist in enumerate(playlists):
    print(f"{idx+1}. Name: {playlist['name']}, ID: {playlist['id']}")
# Out:
# Top 5 Featured Playlists:
# 1. Name: Hot Hits NL, ID: 37i9dQZF1DWSBi5svWQ9Nk
# 2. Name: Kroegenhits 2024, ID: 37i9dQZF1DWUppGmuwT9c7
# 3. Name: Beste van NL, ID: 37i9dQZF1DXdKMCnEhDnDL
# 4. Name: Taylor Swift | The Eras Tour Official Setlist, ID: 37i9dQZF1DX0D996ZXujBy
# 5. Name: Summer Dance Hits 2024, ID: 37i9dQZF1DWZ7eJRBxKzdO

# %%
# Select a playlist (e.g., the first one in the list)
playlist_id = playlists[0]['id']

# Fetch the details of the selected playlist
playlist_details = sp.playlist(playlist_id)
# Display the details
print("\nSelected Playlist Details:")
print(f"Name: {playlist_details['name']}")
print(f"Description: {playlist_details['description']}")
print(f"Total Tracks: {playlist_details['tracks']['total']}")
# Out:
# Selected Playlist Details:
# Name: Hot Hits NL
# Description: De 50 populairste hits van nu. Cover: Shaboozey
# Total Tracks: 50

# %%
# Extract the names of the first 10 tracks
track_items = playlist_details['tracks']['items'][:10]

# Display the names of the first 10 tracks
print("First 10 Tracks:")
track_artist_dict = {}
for idx, item in enumerate(track_items):
    track_name = item['track']['name']
    artist_names = [artist['name'] for artist in item['track']['artists']]
    track_artist_dict[track_name] = artist_names
    print(f"{idx+1}. {track_name}")
# Out:
# First 10 Tracks:
# 1. A Bar Song (Tipsy)
# 2. Huisfeestje
# 3. Stargazing
# 4. Terug In De Tijd
# 5. Queen Of My Castle
# 6. Sugardaddy
# 7. Carry You Home
# 8. Stiekem ‘24
# 9. Belong Together
# 10. Mockingbird

# %%
# Display the dictionary of track names and artist lists
print("Track and Artist Dictionary:")
print(track_artist_dict)
